# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'data/UFRGS/'
df = pd.read_csv(file_path + 'data.csv')
df.head()
# Out:
#    gender  physics  biology  history  SecondLanguage  geography  literature  \
# 0       0   622.60   491.56   439.93          707.64     663.65      557.09
# 1       1   538.00   490.58   406.59          529.05     532.28      447.23
# 2       1   455.18   440.00   570.86          417.54     453.53      425.87
# 3       0   756.91   679.62   531.28          583.63     534.42      521.40
# 4       1   584.54   649.84   637.43          609.06     670.46      515.38
#
#    PortugueseEssay    math  chemistry      GPA
# 0           711.37  731.31     509.80  1.33333
# 1           527.58  379.14     488.64  2.98333
# 2           475.63  476.11     407.15  1.97333
# 3           592.41  783.76     588.26  2.53333
# 4           572.52  581.25     529.04  1.58667

# %%
df['gender'].value_counts()
# Out:
# 1    22335
# 0    20968
# Name: gender, dtype: int64

# %%
gpa_threshold = 3.3
df['GPA_bi'] = df['GPA'].apply(lambda x: int(x >= gpa_threshold))
print(df[['GPA_bi', 'gender', 'math']].groupby(by=['gender', 'GPA_bi']).count())
# Out:
#                 math
# gender GPA_bi
# 0      0       12607
#        1        8361
# 1      0       16914
#        1        5421

# %%
df.shape
# Out:
# (43303, 12)

# %% [markdown]
# ## Downsample population

# %%
ma_df = df.query('gender==1')
mi_df = df.query('gender==0').copy()
sample_ratio = 0.3

# %%
np.random.seed(1)
sampled_indices = np.random.rand(len(mi_df)) < sample_ratio

sampled_mi = mi_df.loc[sampled_indices]
sampled_mi.shape[0]
# Out:
# 6296

# %%
sample_df = pd.concat([ma_df, sampled_mi])
sample_df.reset_index(inplace=True)
sample_df.shape[0]
# Out:
# 28631

# %%
sample_df['gender'].value_counts()
# Out:
# 1    22335
# 0     6296
# Name: gender, dtype: int64

# %%
print(sample_df[['GPA_bi', 'gender', 'math']].groupby(by=['gender', 'GPA_bi']).count())
# Out:
#                 math
# gender GPA_bi
# 0      0        3782
#        1        2514
# 1      0       16914
#        1        5421

# %%
sample_df.drop(columns=['index', 'GPA'], inplace=True)
sample_df.rename(columns={'GPA_bi': 'GPA'}, inplace=True)
sample_df
# Out:
#        gender  physics  biology  history  SecondLanguage  geography  \
# 0           1   538.00   490.58   406.59          529.05     532.28
# 1           1   455.18   440.00   570.86          417.54     453.53
# 2           1   584.54   649.84   637.43          609.06     670.46
# 3           1   325.99   466.74   597.06          554.43     535.77
# 4           1   527.65   559.99   758.37          669.71     645.62
# ...       ...      ...      ...      ...             ...        ...
# 28626       0   482.47   534.23   600.00          499.43     487.11
# 28627       0   565.25   610.70   683.67          657.02     582.79
# 28628       0   646.34   682.52   598.85          645.05     582.52
# 28629       0   586.54   541.77   574.82          657.02     534.42
# 28630       0   512.56   415.41   517.36          532.37     592.30
#
#        literature  PortugueseEssay    math  chemistry  GPA
# 0          447.23           527.58  379.14     488.64    0
# 1          425.87           475.63  476.11     407.15    0
# 2          515.38           572.52  581.25     529.04    0
# 3          717.03           477.60  503.82     422.92    0
# 4          648.67           539.23  470.78     486.13    0
# ...           ...              ...     ...        ...  ...
# 28626      622.29           595.25  405.98     507.95    0
# 28627      673.57           592.41  495.40     566.54    0
# 28628      509.21           550.95  491.42     604.94    0
# 28629      546.76           574.01  416.76     371.09    0
# 28630      382.20           538.35  448.02     496.39    0
#
# [28631 rows x 11 columns]

# %%
sample_df.to_csv('data/UFRGS/data_samples.csv', index=False)

# %%
down_popu_df = pd.read_csv('data/UFRGS/data_samples.csv')
print(down_popu_df[['GPA', 'gender', 'math']].groupby(by=['gender', 'GPA']).count())
# Out:
#              math
# gender GPA
# 0      0    12607
#        1     1262
# 1      0    16914
#        1     5421

# %%
down_pos_df = pd.read_csv('data/UFRGS/data_samples_g0.csv')
print(down_pos_df[['GPA', 'gender', 'math']].groupby(by=['gender', 'GPA']).count())
# Out:
#              math
# gender GPA
# 0      0     3782
#        1     2514
# 1      0    16914
#        1     5421

# %% [markdown]
# ## Downsample positive label

# %%
ma_df = df.query('gender==1')
mi_neg_df = df.query('gender==0 and GPA_bi==0')
mi_pos = df.query('gender==0 and GPA_bi==1').copy()
orig_df = pd.concat([ma_df, mi_neg_df])
orig_df.shape
# Out:
# (34942, 12)

# %%
sample_ratio = 0.1 * mi_neg_df.shape[0]/mi_pos.shape[0]
sample_ratio
# Out:
# 0.1507833991149384

# %%
np.random.seed(1)
sampled_indices = np.random.rand(len(mi_pos)) < sample_ratio

sampled_pos = mi_pos.loc[sampled_indices]
sampled_pos.shape[0]
# Out:
# 1262

# %%
sampled_pos
# Out:
#        gender  physics  biology  history  SecondLanguage  geography  \
# 19          0   714.51   760.38   660.90          521.62     725.30
# 33          0   541.21   594.57   567.04          521.62     423.71
# 35          0   558.19   697.72   469.68          625.22     672.07
# 84          0   505.06   482.71   468.02          456.85     460.69
# 102         0   525.97   662.49   537.93          722.57     513.00
# ...       ...      ...      ...      ...             ...        ...
# 43158       0   664.07   655.35   563.73          554.58     481.27
# 43228       0   628.92   541.03   496.09          602.75     556.57
# 43230       0   749.03   789.19   723.29          650.16     712.93
# 43251       0   522.65   518.79   553.05          583.63     582.79
# 43284       0   558.19   697.72   607.26          625.22     618.12
#
#        literature  PortugueseEssay    math  chemistry      GPA  GPA_bi
# 19         687.42           570.19  719.01     753.44  3.77667       1
# 33         493.88           580.82  581.25     484.16  3.30000       1
# 35         692.05           589.81  567.34     611.12  3.41333       1
# 84         648.67           461.30  535.57     529.77  3.73000       1
# 102        549.81           754.43  534.14     583.29  3.46333       1
# ...           ...              ...     ...        ...      ...     ...
# 43158      664.57           579.14  661.89     703.59  3.40000       1
# 43228      551.71           569.65  643.31     655.45  3.79667       1
# 43230      858.78           640.17  810.15     780.28  3.71000       1
# 43251      673.57           514.72  390.54     436.24  3.30000       1
# 43284      596.69           439.31  543.74     721.86  3.50333       1
#
# [1262 rows x 12 columns]

# %%
sample_df = pd.concat([orig_df, sampled_pos])
sample_df.reset_index(inplace=True)
sample_df.shape[0]
# Out:
# 36204

# %%
print(sample_df[['GPA_bi', 'gender', 'math']].groupby(by=['gender', 'GPA_bi']).count())
# Out:
#                 math
# gender GPA_bi
# 0      0       12607
#        1        1262
# 1      0       16914
#        1        5421

# %%
sample_df.drop(columns=['index', 'GPA'], inplace=True)
sample_df.rename(columns={'GPA_bi': 'GPA'}, inplace=True)
sample_df
# Out:
#        gender  physics  biology  history  SecondLanguage  geography  \
# 0           1   538.00   490.58   406.59          529.05     532.28
# 1           1   455.18   440.00   570.86          417.54     453.53
# 2           1   584.54   649.84   637.43          609.06     670.46
# 3           1   325.99   466.74   597.06          554.43     535.77
# 4           1   527.65   559.99   758.37          669.71     645.62
# ...       ...      ...      ...      ...             ...        ...
# 36199       0   664.07   655.35   563.73          554.58     481.27
# 36200       0   628.92   541.03   496.09          602.75     556.57
# 36201       0   749.03   789.19   723.29          650.16     712.93
# 36202       0   522.65   518.79   553.05          583.63     582.79
# 36203       0   558.19   697.72   607.26          625.22     618.12
#
#        literature  PortugueseEssay    math  chemistry  GPA
# 0          447.23           527.58  379.14     488.64    0
# 1          425.87           475.63  476.11     407.15    0
# 2          515.38           572.52  581.25     529.04    0
# 3          717.03           477.60  503.82     422.92    0
# 4          648.67           539.23  470.78     486.13    0
# ...           ...              ...     ...        ...  ...
# 36199      664.57           579.14  661.89     703.59    1
# 36200      551.71           569.65  643.31     655.45    1
# 36201      858.78           640.17  810.15     780.28    1
# 36202      673.57           514.72  390.54     436.24    1
# 36203      596.69           439.31  543.74     721.86    1
#
# [36204 rows x 11 columns]

# %%
sample_df.to_csv('data/UFRGS/data_samples.csv', index=False)
